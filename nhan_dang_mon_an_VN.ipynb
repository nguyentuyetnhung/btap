# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyentuyetnhung/btap/blob/main/nhan_dang_mon_an_VN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cài đặt thư viện cần thiết
# !pip install -q gradio
# !pip install -q tensorflow

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pickle
import gradio as gr
import matplotlib.pyplot as plt

BASE_DIR = "/content/drive/MyDrive/nhandangdoan"
IMG_SIZE = (60, 60)
BATCH_SIZE = 128
EPOCHS = 300
RANDOM_STATE = 42


CANONICAL_CLASSES = ['banh chung', 'com tam', 'pho', 'banh mi']
CANONICAL_EMOJIS = ['🍚', '🍛', '🍜', '🥖']
CANONICAL_EMOJI_MAP = dict(zip(CANONICAL_CLASSES, CANONICAL_EMOJIS))

LABEL_ENCODER_PATH = os.path.join(BASE_DIR, 'label_encoder.pkl')
FINAL_MODEL_PATH = os.path.join(BASE_DIR, 'final_model.h5')


def is_image_file(filename):
    ext = filename.lower().rsplit('.', 1)
    if len(ext) == 2:
        return ext[1] in ('jpg', 'jpeg', 'png', 'bmp', 'gif', 'tiff', 'webp')
    return False

def load_data(data_dir, class_names, img_size=IMG_SIZE):
    images = []
    labels = []

    for class_name in class_names:
        class_dir = os.path.join(data_dir, class_name)
        if not os.path.isdir(class_dir):
            print(f"[Warning] Thư mục không tồn tại: {class_dir} (bỏ qua)")
            continue

        for img_name in os.listdir(class_dir):
            if not is_image_file(img_name):
                continue
            img_path = os.path.join(class_dir, img_name)
            try:
                img = Image.open(img_path).convert('RGB')
                img = img.resize(img_size)
                img_array = np.array(img, dtype=np.float32) / 255.0

                images.append(img_array)
                labels.append(class_name)
            except Exception as e:
                print(f"Lỗi đọc ảnh {img_path}: {e}")

    if len(images) == 0:
        raise ValueError(f"Không tìm thấy ảnh trong {data_dir}. Kiểm tra đường dẫn và tên thư mục lớp.")

    return np.array(images), np.array(labels)

print("Đang tải dữ liệu từ:", BASE_DIR)
try:
    X, y = load_data(BASE_DIR, CANONICAL_CLASSES, IMG_SIZE)
    print(f"Tổng ảnh: {len(X)}")

    unique, counts = np.unique(y, return_counts=True)
    print("Số lượng theo lớp:")
    for u, c in zip(unique, counts):
        print(f"  - {u}: {c} ảnh")

    missing = [c for c in CANONICAL_CLASSES if c not in unique]
    if missing:
        print(f"[Lưu ý] Không tìm thấy ảnh cho các lớp: {missing}")

except Exception as e:
    print(f"Lỗi khi tải dữ liệu: {e}")
    print("Tạo dữ liệu mẫu để demo...")

    X = np.random.rand(40, IMG_SIZE[0], IMG_SIZE[1], 3).astype(np.float32)
    y = np.array(['banh chung']*10 + ['com tam']*10 + ['pho']*10 + ['banh mi']*10)


label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)

X_flat = X.reshape(X.shape[0], IMG_SIZE[0] * IMG_SIZE[1] * 3)
y_categorical = to_categorical(y_encoded, num_classes=num_classes)

# Lưu label encoder
with open(LABEL_ENCODER_PATH, 'wb') as f:
    pickle.dump({'label_encoder': label_encoder, 'trained_classes': label_encoder.classes_.tolist()}, f)
print(f"Đã lưu label encoder -> {LABEL_ENCODER_PATH}")


min_count = np.min(np.bincount(y_encoded)) if len(y_encoded) > 0 else 0
if min_count < 2:
    print('[Warning] Ít hơn 2 ảnh cho một hoặc nhiều lớp. Sẽ không dùng stratify để chia dữ liệu.')
    stratify_param = None
else:
    stratify_param = y_encoded

x_train, x_test, y_train, y_test = train_test_split(
    X_flat, y_categorical, test_size=0.2, random_state=RANDOM_STATE, stratify=stratify_param
)

print(f"Kích thước train: {x_train.shape}, test: {x_test.shape}")

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(IMG_SIZE[0]*IMG_SIZE[1]*3,)))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(
    optimizer="rmsprop",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
-
print("Bắt đầu huấn luyện...")
history = model.fit(
    x_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(x_test, y_test),
    verbose=1
)

model.save(FINAL_MODEL_PATH)
print(f"Đã lưu mô hình cuối cùng -> {FINAL_MODEL_PATH}")


print("Đang đánh giá trên tập test...")
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Độ chính xác trên tập test: {test_acc:.4f}")

try:
    with open(LABEL_ENCODER_PATH, 'rb') as f:
        le_data = pickle.load(f)
        label_encoder = le_data['label_encoder']
        trained_classes = le_data.get('trained_classes', label_encoder.classes_.tolist())
except:
    print("Không thể load label encoder, sử dụng encoder hiện tại")
    trained_classes = label_encoder.classes_.tolist()


emoji_map = {c: CANONICAL_EMOJI_MAP.get(c, '🍽️') for c in trained_classes}


def predict_image(img):
    if img is None:
        return "<p style='color: red;'>Không có ảnh được tải lên.</p>"

    try:
        img_proc = img.resize(IMG_SIZE).convert('RGB')
        arr = np.array(img_proc, dtype=np.float32) / 255.0

        arr_flat = arr.reshape(1, IMG_SIZE[0] * IMG_SIZE[1] * 3)

        preds = model.predict(arr_flat, verbose=0)
        pred_idx = int(np.argmax(preds, axis=1)[0])


        class_name = label_encoder.inverse_transform([pred_idx])[0]
        confidence = float(np.max(preds))

        # Lấy emoji (nếu có)
        emoji = emoji_map.get(class_name, '🍽️')

        # Gradient màu theo độ tin cậy
        if confidence > 0.7:
            color_gradient = "linear-gradient(135deg, #43e97b 0%, #38f9d7 100%)"
        elif confidence > 0.5:
            color_gradient = "linear-gradient(135deg, #fa709a 0%, #fee140 100%)"
        else:
            color_gradient = "linear-gradient(135deg, #ff5858 0%, #f09819 100%)"


        per_class_html = ""
        for i, cname in enumerate(label_encoder.classes_):
            cemoji = emoji_map.get(cname, '🍽️')
            per_class_html += f"<p style=\"margin:5px 0;font-size:14px;\">{cemoji} {cname}: {preds[0][i]:.2%}</p>"

        result = f"""
        <div style="text-align: center; padding: 25px; background: {color_gradient};
                    border-radius: 20px; color: white; box-shadow: 0 10px 30px rgba(0,0,0,0.2);">
            <h2 style="margin: 0; font-size: 28px; font-weight: bold;">{emoji} {class_name}</h2>
            <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 15px; margin: 15px 0;">
                <p style="margin: 0; font-size: 20px;">Độ tin cậy: <strong>{confidence:.2%}</strong></p>
            </div>
            <div style="background: rgba(0,0,0,0.1); padding: 10px; border-radius: 10px;">
                <p style="margin: 0; font-size: 16px;">Xác suất cho các món:</p>
                {per_class_html}
            </div>
        </div>
        """

        return result

    except Exception as e:
        return f"<p style='color:red;'>Lỗi khi dự đoán: {str(e)}</p>"


css = """
body {background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); min-height: 100vh; margin: 0; padding: 20px;}
.gr-box {background: rgba(255, 255, 255, 0.95) !important; border-radius: 20px !important; padding: 25px !important;
         box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2) !important; border: none !important;}
.gr-button {background: linear-gradient(135deg, #6a11cb 0%, #2575fc 100%) !important; color: white !important;
            border: none !important; border-radius: 10px !important; padding: 15px 30px !important;
            font-size: 18px !important; font-weight: bold !important; transition: all 0.3s ease !important;
            cursor: pointer !important; margin-top: 15px !important;}
.gr-button:hover {transform: translateY(-3px) !important; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.3) !important;}
.footer {text-align: center; margin-top: 30px; color: rgba(255,255,255,0.7); font-size: 0.9em;}
.instructions {background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 15px; color: white; margin-bottom: 20px;}
"""

with gr.Blocks(css=css, theme=gr.themes.Soft()) as demo:
    gr.Markdown(
        """
        # 🍜 Nhận Diện Món Ăn Việt Nam
        <div style="text-align: center; color: #555; margin-bottom: 20px; font-size: 18px;">
            Ứng dụng trí tuệ nhân tạo nhận diện các món ăn Việt Nam
        </div>
        """
    )

    with gr.Row():
        with gr.Column(scale=1, min_width=300):
            gr.Markdown("### 📸 Tải lên hình ảnh món ăn")
            image_input = gr.Image(type="pil", label="", height=300)
            predict_btn = gr.Button("🔍 Nhận diện món ăn")

            gr.Markdown("### 🍽️ Món ăn được hỗ trợ")
            for i, cls in enumerate(CANONICAL_CLASSES):
                gr.Markdown(f"{CANONICAL_EMOJIS[i]} **{cls}**")

        with gr.Column(scale=1, min_width=300):
            gr.Markdown("### 🔍 Kết quả nhận diện")
            output_html = gr.HTML()

    with gr.Row():
        with gr.Accordion("📖 Hướng dẫn sử dụng", open=False):
            gr.Markdown("""
            1. **Tải lên hình ảnh**: Click vào khung ảnh hoặc kéo thả ảnh vào
            2. **Nhận diện**: Nhấn nút "Nhận diện món ăn"
            3. **Xem kết quả**: Kết quả sẽ hiển thị ở khung bên phải

            **Lưu ý**: Ảnh càng rõ nét thì kết quả càng chính xác!
            """)

    predict_btn.click(fn=predict_image, inputs=image_input, outputs=output_html)

    gr.Markdown(
        f"""
        <div class="footer">
            Ứng dụng nhận diện món ăn Việt Nam | Sử dụng mạng ANN | Độ chính xác (test): {test_acc*100:.2f}%
        </div>
        """
    )

# Chạy giao diện
print("Giao diện nhận diện món ăn đã sẵn sàng!")
try:
    demo.launch(share=True, debug=True)
except Exception as e:
    print(f"Lỗi khi khởi chạy Gradio: {e}")
    print("Thử chạy với cờ share=False...")
    demo.launch(share=False, debug=True)
# Out:
# Mounted at /content/drive
# Đang tải dữ liệu từ: /content/drive/MyDrive/nhandangdoan
# Tổng ảnh: 84
# Số lượng theo lớp:
#   - banh chung: 21 ảnh
#   - banh mi: 21 ảnh
#   - com tam: 21 ảnh
#   - pho: 21 ảnh
# Đã lưu label encoder -> /content/drive/MyDrive/nhandangdoan/label_encoder.pkl
# Kích thước train: (67, 10800), test: (17, 10800)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                │ (None, 512)            │     5,530,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,662,468 (21.60 MB)
#  Trainable params: 5,662,468 (21.60 MB)
#  Non-trainable params: 0 (0.00 B)
# Bắt đầu huấn luyện...
# Epoch 1/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1493 - loss: 1.5903 - val_accuracy: 0.2353 - val_loss: 43.7879
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.2537 - loss: 39.8987 - val_accuracy: 0.2353 - val_loss: 32.2257
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.2687 - loss: 29.8147 - val_accuracy: 0.2941 - val_loss: 33.5661
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.2090 - loss: 32.1412 - val_accuracy: 0.2353 - val_loss: 14.7722
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.2537 - loss: 13.3349 - val_accuracy: 0.2941 - val_loss: 6.1970
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.2985 - loss: 9.2807 - val_accuracy: 0.2353 - val_loss: 7.3813
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.2836 - loss: 7.3157 - val_accuracy: 0.2941 - val_loss: 3.7249
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.2537 - loss: 5.6344 - val_accuracy: 0.2353 - val_loss: 2.8225
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.2836 - loss: 4.4124 - val_accuracy: 0.2353 - val_loss: 2.8500
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.2537 - loss: 5.1917 - val_accuracy: 0.2941 - val_loss: 3.5461
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.2687 - loss: 4.3276 - val_accuracy: 0.2353 - val_loss: 1.6271
# Epoch 12/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.2985 - loss: 2.5137 - val_accuracy: 0.4706 - val_loss: 1.2311
# Epoch 13/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.3881 - loss: 2.4610 - val_accuracy: 0.2941 - val_loss: 1.8196
# Epoch 14/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.3433 - loss: 2.6241 - val_accuracy: 0.2353 - val_loss: 2.4147
# Epoch 15/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.2537 - loss: 3.1219 - val_accuracy: 0.2353 - val_loss: 1.6990
# Epoch 16/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.2836 - loss: 2.7288 - val_accuracy: 0.4118 - val_loss: 1.2950
# Epoch 17/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.3433 - loss: 2.1216 - val_accuracy: 0.4706 - val_loss: 1.3330
# Epoch 18/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.4478 - loss: 1.4717 - val_accuracy: 0.3529 - val_loss: 1.3853
# Epoch 19/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.3731 - loss: 1.6193 - val_accuracy: 0.2941 - val_loss: 1.5547
# Epoch 20/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.4179 - loss: 1.4553 - val_accuracy: 0.4706 - val_loss: 1.4567
# Epoch 21/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4030 - loss: 1.6300 - val_accuracy: 0.4118 - val_loss: 1.4400
# Epoch 22/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.4030 - loss: 1.4897 - val_accuracy: 0.3529 - val_loss: 1.2888
# Epoch 23/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4627 - loss: 1.2924 - val_accuracy: 0.2353 - val_loss: 1.8760
# Epoch 24/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.3881 - loss: 1.7152 - val_accuracy: 0.2941 - val_loss: 1.5214
# Epoch 25/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.4478 - loss: 1.5653 - val_accuracy: 0.4706 - val_loss: 1.3774
# Epoch 26/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4627 - loss: 1.3014 - val_accuracy: 0.4706 - val_loss: 1.2577
# Epoch 27/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.4627 - loss: 1.2714 - val_accuracy: 0.2941 - val_loss: 1.2074
# Epoch 28/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.3134 - loss: 1.4182 - val_accuracy: 0.4118 - val_loss: 1.5898
# Epoch 29/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.4328 - loss: 1.5410 - val_accuracy: 0.2353 - val_loss: 1.7233
# Epoch 30/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.3284 - loss: 1.5929 - val_accuracy: 0.4706 - val_loss: 1.4596
# Epoch 31/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.4179 - loss: 1.4887 - val_accuracy: 0.4118 - val_loss: 1.3644
# Epoch 32/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3881 - loss: 1.4994 - val_accuracy: 0.3529 - val_loss: 1.2374
# Epoch 33/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.5522 - loss: 1.1582 - val_accuracy: 0.2941 - val_loss: 1.3717
# Epoch 34/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4925 - loss: 1.3975 - val_accuracy: 0.5882 - val_loss: 1.2192
# Epoch 35/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.3582 - loss: 1.2513 - val_accuracy: 0.5882 - val_loss: 1.1973
# Epoch 36/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.4328 - loss: 1.2224 - val_accuracy: 0.2941 - val_loss: 1.5195
# Epoch 37/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.3433 - loss: 1.5998 - val_accuracy: 0.4118 - val_loss: 1.2956
# Epoch 38/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.4179 - loss: 1.2650 - val_accuracy: 0.3529 - val_loss: 1.3294
# Epoch 39/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.4179 - loss: 1.2830 - val_accuracy: 0.3529 - val_loss: 1.8617
# Epoch 40/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.4030 - loss: 1.6628 - val_accuracy: 0.4706 - val_loss: 1.3284
# Epoch 41/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.3433 - loss: 1.7967 - val_accuracy: 0.4706 - val_loss: 1.3942
# Epoch 42/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.3582 - loss: 1.5633 - val_accuracy: 0.3529 - val_loss: 1.3974
# Epoch 43/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4179 - loss: 1.3849 - val_accuracy: 0.3529 - val_loss: 1.2572
# Epoch 44/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.4627 - loss: 1.2751 - val_accuracy: 0.2941 - val_loss: 1.6400
# Epoch 45/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.3433 - loss: 1.7166 - val_accuracy: 0.4118 - val_loss: 1.6668
# Epoch 46/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.3134 - loss: 1.6768 - val_accuracy: 0.2941 - val_loss: 1.5024
# Epoch 47/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.4030 - loss: 1.3751 - val_accuracy: 0.5294 - val_loss: 1.2104
# Epoch 48/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4478 - loss: 1.1628 - val_accuracy: 0.4118 - val_loss: 1.3522
# Epoch 49/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4030 - loss: 1.3544 - val_accuracy: 0.4706 - val_loss: 1.3448
# Epoch 50/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.3881 - loss: 1.2334 - val_accuracy: 0.2941 - val_loss: 1.4181
# Epoch 51/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.4030 - loss: 1.3757 - val_accuracy: 0.4706 - val_loss: 1.2496
# Epoch 52/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5373 - loss: 1.1562 - val_accuracy: 0.5294 - val_loss: 1.1612
# Epoch 53/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5224 - loss: 1.0292 - val_accuracy: 0.2941 - val_loss: 1.3096
# Epoch 54/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.3881 - loss: 1.2750 - val_accuracy: 0.3529 - val_loss: 1.2844
# Epoch 55/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.4030 - loss: 1.2125 - val_accuracy: 0.2941 - val_loss: 1.2553
# Epoch 56/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.4478 - loss: 1.1587 - val_accuracy: 0.4706 - val_loss: 1.2291
# Epoch 57/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.4627 - loss: 1.1568 - val_accuracy: 0.4706 - val_loss: 1.2308
# Epoch 58/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.4627 - loss: 1.1324 - val_accuracy: 0.4706 - val_loss: 1.3083
# Epoch 59/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.4776 - loss: 1.1107 - val_accuracy: 0.4118 - val_loss: 1.3250
# Epoch 60/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.4030 - loss: 1.2091 - val_accuracy: 0.5294 - val_loss: 1.1298
# Epoch 61/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4328 - loss: 1.0696 - val_accuracy: 0.5294 - val_loss: 1.1869
# Epoch 62/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5373 - loss: 1.0383 - val_accuracy: 0.5294 - val_loss: 1.2452
# Epoch 63/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.4030 - loss: 1.2237 - val_accuracy: 0.4706 - val_loss: 1.2530
# Epoch 64/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.6119 - loss: 0.9714 - val_accuracy: 0.5294 - val_loss: 1.1250
# Epoch 65/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6119 - loss: 0.9295 - val_accuracy: 0.5294 - val_loss: 1.1774
# Epoch 66/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.6567 - loss: 0.9181 - val_accuracy: 0.4706 - val_loss: 1.1765
# Epoch 67/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step - accuracy: 0.6119 - loss: 0.9962 - val_accuracy: 0.4118 - val_loss: 1.3836
# Epoch 68/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5224 - loss: 1.0592 - val_accuracy: 0.5294 - val_loss: 1.3222
# Epoch 69/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.5075 - loss: 1.2848 - val_accuracy: 0.3529 - val_loss: 1.1690
# Epoch 70/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.5522 - loss: 1.0414 - val_accuracy: 0.4118 - val_loss: 1.1255
# Epoch 71/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.5821 - loss: 0.9519 - val_accuracy: 0.5882 - val_loss: 1.1637
# Epoch 72/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.5075 - loss: 1.0392 - val_accuracy: 0.2941 - val_loss: 1.3945
# Epoch 73/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.4328 - loss: 1.2802 - val_accuracy: 0.4118 - val_loss: 1.2081
# Epoch 74/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.4776 - loss: 1.1090 - val_accuracy: 0.6471 - val_loss: 1.1672
# Epoch 75/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5373 - loss: 1.0374 - val_accuracy: 0.4118 - val_loss: 1.2157
# Epoch 76/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6119 - loss: 0.9389 - val_accuracy: 0.6471 - val_loss: 1.0868
# Epoch 77/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6567 - loss: 0.8897 - val_accuracy: 0.3529 - val_loss: 1.3511
# Epoch 78/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.6269 - loss: 0.8711 - val_accuracy: 0.4706 - val_loss: 1.4254
# Epoch 79/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.5075 - loss: 1.2063 - val_accuracy: 0.4118 - val_loss: 1.2800
# Epoch 80/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4925 - loss: 1.1774 - val_accuracy: 0.5882 - val_loss: 1.1154
# Epoch 81/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.6418 - loss: 0.9569 - val_accuracy: 0.4706 - val_loss: 1.4236
# Epoch 82/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5821 - loss: 0.9116 - val_accuracy: 0.4706 - val_loss: 1.7502
# Epoch 83/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4776 - loss: 1.4370 - val_accuracy: 0.5294 - val_loss: 1.8584
# Epoch 84/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.3582 - loss: 1.8715 - val_accuracy: 0.4118 - val_loss: 1.2287
# Epoch 85/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.4925 - loss: 1.0627 - val_accuracy: 0.5294 - val_loss: 1.0540
# Epoch 86/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6716 - loss: 0.9357 - val_accuracy: 0.5294 - val_loss: 0.9717
# Epoch 87/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.6866 - loss: 0.7974 - val_accuracy: 0.5294 - val_loss: 1.0154
# Epoch 88/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.7910 - loss: 0.7084 - val_accuracy: 0.4706 - val_loss: 1.0622
# Epoch 89/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.7761 - loss: 0.6623 - val_accuracy: 0.5882 - val_loss: 0.9944
# Epoch 90/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6716 - loss: 0.7146 - val_accuracy: 0.4118 - val_loss: 1.5236
# Epoch 91/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5522 - loss: 1.1256 - val_accuracy: 0.4706 - val_loss: 1.2461
# Epoch 92/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.5970 - loss: 1.0557 - val_accuracy: 0.5294 - val_loss: 1.3084
# Epoch 93/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5821 - loss: 0.9585 - val_accuracy: 0.4118 - val_loss: 1.3323
# Epoch 94/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5075 - loss: 1.0316 - val_accuracy: 0.5882 - val_loss: 0.9885
# Epoch 95/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.7015 - loss: 0.8060 - val_accuracy: 0.5294 - val_loss: 1.1577
# Epoch 96/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.6866 - loss: 0.7730 - val_accuracy: 0.5294 - val_loss: 1.2201
# Epoch 97/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5672 - loss: 1.0228 - val_accuracy: 0.4706 - val_loss: 1.2542
# Epoch 98/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.6269 - loss: 0.8547 - val_accuracy: 0.5294 - val_loss: 1.0483
# Epoch 99/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.7164 - loss: 0.7699 - val_accuracy: 0.4706 - val_loss: 1.1772
# Epoch 100/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.6716 - loss: 0.8046 - val_accuracy: 0.6471 - val_loss: 1.0701
# Epoch 101/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5821 - loss: 0.8368 - val_accuracy: 0.4118 - val_loss: 1.5203
# Epoch 102/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.5373 - loss: 1.2459 - val_accuracy: 0.4118 - val_loss: 1.2542
# Epoch 103/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6119 - loss: 1.1034 - val_accuracy: 0.4118 - val_loss: 1.4606
# Epoch 104/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5373 - loss: 1.0806 - val_accuracy: 0.5882 - val_loss: 1.1308
# Epoch 105/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.6418 - loss: 0.8528 - val_accuracy: 0.4706 - val_loss: 1.0821
# Epoch 106/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5224 - loss: 0.9956 - val_accuracy: 0.5882 - val_loss: 1.1224
# Epoch 107/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5821 - loss: 0.8480 - val_accuracy: 0.4706 - val_loss: 1.2185
# Epoch 108/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5522 - loss: 0.9532 - val_accuracy: 0.4118 - val_loss: 1.3313
# Epoch 109/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5970 - loss: 0.8445 - val_accuracy: 0.4706 - val_loss: 1.2210
# Epoch 110/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.5373 - loss: 0.9422 - val_accuracy: 0.4118 - val_loss: 1.6036
# Epoch 111/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.4776 - loss: 1.3485 - val_accuracy: 0.6471 - val_loss: 1.0085
# Epoch 112/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.6567 - loss: 0.7299 - val_accuracy: 0.5882 - val_loss: 0.9876
# Epoch 113/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.6567 - loss: 0.7327 - val_accuracy: 0.4706 - val_loss: 1.2888
# Epoch 114/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.6269 - loss: 1.0633 - val_accuracy: 0.4118 - val_loss: 1.1421
# Epoch 115/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.5821 - loss: 0.9106 - val_accuracy: 0.3529 - val_loss: 1.4027
# Epoch 116/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6269 - loss: 0.8836 - val_accuracy: 0.5294 - val_loss: 1.0209
# Epoch 117/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.7761 - loss: 0.6753 - val_accuracy: 0.5294 - val_loss: 1.0898
# Epoch 118/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.7463 - loss: 0.6867 - val_accuracy: 0.5294 - val_loss: 1.0652
# Epoch 119/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8060 - loss: 0.6002 - val_accuracy: 0.5882 - val_loss: 1.0332
# Epoch 120/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.8060 - loss: 0.5489 - val_accuracy: 0.5882 - val_loss: 1.1108
# Epoch 121/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.7612 - loss: 0.5923 - val_accuracy: 0.5294 - val_loss: 1.0648
# Epoch 122/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.6418 - loss: 0.7879 - val_accuracy: 0.5294 - val_loss: 1.4672
# Epoch 123/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5970 - loss: 0.9090 - val_accuracy: 0.3529 - val_loss: 1.4536
# Epoch 124/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.5970 - loss: 1.2418 - val_accuracy: 0.4118 - val_loss: 1.3495
# Epoch 125/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.6866 - loss: 0.8882 - val_accuracy: 0.5294 - val_loss: 1.0607
# Epoch 126/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.6418 - loss: 0.8320 - val_accuracy: 0.7059 - val_loss: 1.1319
# Epoch 127/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7612 - loss: 0.7150 - val_accuracy: 0.5294 - val_loss: 1.2352
# Epoch 128/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.5075 - loss: 0.9920 - val_accuracy: 0.4118 - val_loss: 1.1702
# Epoch 129/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6418 - loss: 0.9312 - val_accuracy: 0.5882 - val_loss: 0.9581
# Epoch 130/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.8209 - loss: 0.5570 - val_accuracy: 0.5882 - val_loss: 1.0213
# Epoch 131/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7313 - loss: 0.5739 - val_accuracy: 0.5882 - val_loss: 1.3022
# Epoch 132/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7463 - loss: 0.6099 - val_accuracy: 0.4706 - val_loss: 1.4335
# Epoch 133/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6866 - loss: 0.9242 - val_accuracy: 0.5294 - val_loss: 1.1487
# Epoch 134/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7612 - loss: 0.6205 - val_accuracy: 0.5294 - val_loss: 1.1337
# Epoch 135/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.6866 - loss: 0.8021 - val_accuracy: 0.4706 - val_loss: 1.9566
# Epoch 136/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.5075 - loss: 1.2487 - val_accuracy: 0.4118 - val_loss: 2.3903
# Epoch 137/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.4478 - loss: 1.9967 - val_accuracy: 0.4706 - val_loss: 1.1965
# Epoch 138/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5970 - loss: 0.8388 - val_accuracy: 0.4706 - val_loss: 1.0935
# Epoch 139/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.6567 - loss: 0.7658 - val_accuracy: 0.5294 - val_loss: 0.9869
# Epoch 140/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7015 - loss: 0.7639 - val_accuracy: 0.5882 - val_loss: 1.0107
# Epoch 141/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8209 - loss: 0.5530 - val_accuracy: 0.5294 - val_loss: 1.1476
# Epoch 142/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8060 - loss: 0.5403 - val_accuracy: 0.4706 - val_loss: 1.4049
# Epoch 143/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.6567 - loss: 0.8289 - val_accuracy: 0.5882 - val_loss: 1.4488
# Epoch 144/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7015 - loss: 0.7340 - val_accuracy: 0.5294 - val_loss: 1.0632
# Epoch 145/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.6269 - loss: 0.7438 - val_accuracy: 0.2353 - val_loss: 1.4832
# Epoch 146/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6866 - loss: 0.7515 - val_accuracy: 0.4706 - val_loss: 1.1501
# Epoch 147/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.7463 - loss: 0.5946 - val_accuracy: 0.5294 - val_loss: 1.2525
# Epoch 148/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.7910 - loss: 0.5627 - val_accuracy: 0.5294 - val_loss: 0.9318
# Epoch 149/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.8060 - loss: 0.5722 - val_accuracy: 0.5882 - val_loss: 1.0235
# Epoch 150/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8209 - loss: 0.5401 - val_accuracy: 0.5294 - val_loss: 1.0995
# Epoch 151/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7761 - loss: 0.4625 - val_accuracy: 0.4118 - val_loss: 1.6404
# Epoch 152/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.6269 - loss: 0.8560 - val_accuracy: 0.5882 - val_loss: 1.1626
# Epoch 153/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.7015 - loss: 0.7671 - val_accuracy: 0.5294 - val_loss: 1.3371
# Epoch 154/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6866 - loss: 0.6761 - val_accuracy: 0.5294 - val_loss: 1.0578
# Epoch 155/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8060 - loss: 0.6246 - val_accuracy: 0.4118 - val_loss: 1.3890
# Epoch 156/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.7015 - loss: 0.6844 - val_accuracy: 0.5294 - val_loss: 1.4674
# Epoch 157/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.7015 - loss: 0.7291 - val_accuracy: 0.4706 - val_loss: 1.4284
# Epoch 158/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.6119 - loss: 0.8174 - val_accuracy: 0.5294 - val_loss: 1.0431
# Epoch 159/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8507 - loss: 0.5070 - val_accuracy: 0.5294 - val_loss: 1.2177
# Epoch 160/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6418 - loss: 0.7751 - val_accuracy: 0.4706 - val_loss: 1.6175
# Epoch 161/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6269 - loss: 0.9079 - val_accuracy: 0.4118 - val_loss: 1.1858
# Epoch 162/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6567 - loss: 0.6916 - val_accuracy: 0.5882 - val_loss: 1.1782
# Epoch 163/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7612 - loss: 0.5275 - val_accuracy: 0.4706 - val_loss: 1.1774
# Epoch 164/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8806 - loss: 0.4181 - val_accuracy: 0.6471 - val_loss: 1.2805
# Epoch 165/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8060 - loss: 0.5703 - val_accuracy: 0.5294 - val_loss: 1.3307
# Epoch 166/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6418 - loss: 0.8159 - val_accuracy: 0.5294 - val_loss: 1.6906
# Epoch 167/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6567 - loss: 0.9334 - val_accuracy: 0.5882 - val_loss: 1.1217
# Epoch 168/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.7313 - loss: 0.5967 - val_accuracy: 0.5882 - val_loss: 0.8749
# Epoch 169/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.7612 - loss: 0.5615 - val_accuracy: 0.5882 - val_loss: 0.9988
# Epoch 170/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.8209 - loss: 0.4670 - val_accuracy: 0.5294 - val_loss: 1.5658
# Epoch 171/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7164 - loss: 0.6288 - val_accuracy: 0.4706 - val_loss: 1.1590
# Epoch 172/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.8060 - loss: 0.4943 - val_accuracy: 0.6471 - val_loss: 0.9083
# Epoch 173/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.8955 - loss: 0.4075 - val_accuracy: 0.5294 - val_loss: 1.2210
# Epoch 174/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.8358 - loss: 0.3173 - val_accuracy: 0.5882 - val_loss: 1.4383
# Epoch 175/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7164 - loss: 0.6675 - val_accuracy: 0.4706 - val_loss: 1.6447
# Epoch 176/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.6119 - loss: 1.0351 - val_accuracy: 0.5294 - val_loss: 1.4280
# Epoch 177/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.7761 - loss: 0.6380 - val_accuracy: 0.6471 - val_loss: 1.0489
# Epoch 178/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.7761 - loss: 0.5602 - val_accuracy: 0.4706 - val_loss: 1.1166
# Epoch 179/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.7910 - loss: 0.5065 - val_accuracy: 0.6471 - val_loss: 1.0301
# Epoch 180/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7463 - loss: 0.5568 - val_accuracy: 0.5294 - val_loss: 1.3856
# Epoch 181/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7910 - loss: 0.4436 - val_accuracy: 0.5294 - val_loss: 1.1852
# Epoch 182/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.8657 - loss: 0.4497 - val_accuracy: 0.5294 - val_loss: 1.2162
# Epoch 183/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7910 - loss: 0.5105 - val_accuracy: 0.5294 - val_loss: 1.3792
# Epoch 184/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.8209 - loss: 0.4924 - val_accuracy: 0.5882 - val_loss: 1.3530
# Epoch 185/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8060 - loss: 0.4089 - val_accuracy: 0.6471 - val_loss: 1.0688
# Epoch 186/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.8060 - loss: 0.4237 - val_accuracy: 0.4706 - val_loss: 1.0181
# Epoch 187/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8507 - loss: 0.3569 - val_accuracy: 0.5882 - val_loss: 1.2544
# Epoch 188/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8507 - loss: 0.3735 - val_accuracy: 0.4706 - val_loss: 1.4002
# Epoch 189/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8358 - loss: 0.4156 - val_accuracy: 0.5294 - val_loss: 1.2301
# Epoch 190/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7761 - loss: 0.5379 - val_accuracy: 0.4118 - val_loss: 1.2256
# Epoch 191/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7015 - loss: 0.6950 - val_accuracy: 0.4118 - val_loss: 1.1537
# Epoch 192/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8060 - loss: 0.4771 - val_accuracy: 0.5882 - val_loss: 1.1906
# Epoch 193/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8657 - loss: 0.2898 - val_accuracy: 0.5294 - val_loss: 1.5531
# Epoch 194/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.7164 - loss: 0.7565 - val_accuracy: 0.5294 - val_loss: 1.8412
# Epoch 195/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.6567 - loss: 0.9330 - val_accuracy: 0.5294 - val_loss: 1.4355
# Epoch 196/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.7164 - loss: 0.5814 - val_accuracy: 0.4118 - val_loss: 1.7138
# Epoch 197/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.5821 - loss: 1.1991 - val_accuracy: 0.4118 - val_loss: 1.2888
# Epoch 198/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.7313 - loss: 0.6343 - val_accuracy: 0.5294 - val_loss: 1.0134
# Epoch 199/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.7910 - loss: 0.4688 - val_accuracy: 0.5882 - val_loss: 1.2736
# Epoch 200/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8806 - loss: 0.3421 - val_accuracy: 0.5294 - val_loss: 1.2594
# Epoch 201/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.8806 - loss: 0.3262 - val_accuracy: 0.6471 - val_loss: 0.9885
# Epoch 202/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8657 - loss: 0.3176 - val_accuracy: 0.4706 - val_loss: 1.5873
# Epoch 203/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8507 - loss: 0.4080 - val_accuracy: 0.4706 - val_loss: 1.1836
# Epoch 204/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8955 - loss: 0.3367 - val_accuracy: 0.2941 - val_loss: 2.5046
# Epoch 205/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.6567 - loss: 1.2245 - val_accuracy: 0.3529 - val_loss: 1.4786
# Epoch 206/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6716 - loss: 0.8870 - val_accuracy: 0.5882 - val_loss: 1.0197
# Epoch 207/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7612 - loss: 0.4984 - val_accuracy: 0.4706 - val_loss: 1.2610
# Epoch 208/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7910 - loss: 0.4782 - val_accuracy: 0.5882 - val_loss: 1.3138
# Epoch 209/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8209 - loss: 0.4985 - val_accuracy: 0.4118 - val_loss: 1.2789
# Epoch 210/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7910 - loss: 0.4050 - val_accuracy: 0.5294 - val_loss: 1.1694
# Epoch 211/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8209 - loss: 0.3814 - val_accuracy: 0.5294 - val_loss: 1.5146
# Epoch 212/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8507 - loss: 0.3588 - val_accuracy: 0.5882 - val_loss: 1.2858
# Epoch 213/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8507 - loss: 0.3120 - val_accuracy: 0.5294 - val_loss: 1.0530
# Epoch 214/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9104 - loss: 0.3237 - val_accuracy: 0.6471 - val_loss: 1.0307
# Epoch 215/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9254 - loss: 0.2910 - val_accuracy: 0.5294 - val_loss: 1.1590
# Epoch 216/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8358 - loss: 0.3701 - val_accuracy: 0.4706 - val_loss: 1.3270
# Epoch 217/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8806 - loss: 0.3057 - val_accuracy: 0.4118 - val_loss: 2.0413
# Epoch 218/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7313 - loss: 0.8740 - val_accuracy: 0.5294 - val_loss: 1.6867
# Epoch 219/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6119 - loss: 1.2197 - val_accuracy: 0.4118 - val_loss: 1.4460
# Epoch 220/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.7910 - loss: 0.5034 - val_accuracy: 0.5882 - val_loss: 1.2562
# Epoch 221/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.8060 - loss: 0.5319 - val_accuracy: 0.5882 - val_loss: 1.3412
# Epoch 222/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step - accuracy: 0.8507 - loss: 0.3704 - val_accuracy: 0.5294 - val_loss: 1.0937
# Epoch 223/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8209 - loss: 0.3569 - val_accuracy: 0.4118 - val_loss: 1.5291
# Epoch 224/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.7910 - loss: 0.4406 - val_accuracy: 0.5294 - val_loss: 1.3795
# Epoch 225/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.8806 - loss: 0.3393 - val_accuracy: 0.5882 - val_loss: 1.4624
# Epoch 226/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.8806 - loss: 0.2673 - val_accuracy: 0.4706 - val_loss: 1.2416
# Epoch 227/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9701 - loss: 0.1762 - val_accuracy: 0.4706 - val_loss: 1.3074
# Epoch 228/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8955 - loss: 0.2349 - val_accuracy: 0.5294 - val_loss: 1.2761
# Epoch 229/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 0.9104 - loss: 0.2329 - val_accuracy: 0.5294 - val_loss: 1.3928
# Epoch 230/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9851 - loss: 0.1287 - val_accuracy: 0.4706 - val_loss: 1.2937
# Epoch 231/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9403 - loss: 0.1579 - val_accuracy: 0.5294 - val_loss: 1.5147
# Epoch 232/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9552 - loss: 0.1425 - val_accuracy: 0.5882 - val_loss: 1.4141
# Epoch 233/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8806 - loss: 0.2504 - val_accuracy: 0.5294 - val_loss: 1.5622
# Epoch 234/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.8657 - loss: 0.3753 - val_accuracy: 0.4706 - val_loss: 1.6760
# Epoch 235/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.7313 - loss: 0.7776 - val_accuracy: 0.5294 - val_loss: 1.5998
# Epoch 236/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8060 - loss: 0.5681 - val_accuracy: 0.5882 - val_loss: 1.3603
# Epoch 237/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7463 - loss: 0.5339 - val_accuracy: 0.4706 - val_loss: 1.7369
# Epoch 238/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8060 - loss: 0.5134 - val_accuracy: 0.5294 - val_loss: 1.9448
# Epoch 239/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7612 - loss: 0.6194 - val_accuracy: 0.2941 - val_loss: 2.2261
# Epoch 240/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.6119 - loss: 1.0415 - val_accuracy: 0.2941 - val_loss: 1.3769
# Epoch 241/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.7164 - loss: 0.5652 - val_accuracy: 0.6471 - val_loss: 1.3067
# Epoch 242/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7761 - loss: 0.4696 - val_accuracy: 0.4706 - val_loss: 1.9561
# Epoch 243/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7463 - loss: 0.7841 - val_accuracy: 0.4706 - val_loss: 1.2580
# Epoch 244/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8358 - loss: 0.3801 - val_accuracy: 0.4706 - val_loss: 1.1072
# Epoch 245/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8358 - loss: 0.3403 - val_accuracy: 0.5882 - val_loss: 1.1483
# Epoch 246/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9403 - loss: 0.2131 - val_accuracy: 0.6471 - val_loss: 1.1825
# Epoch 247/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8657 - loss: 0.2932 - val_accuracy: 0.5294 - val_loss: 1.2120
# Epoch 248/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.8657 - loss: 0.2659 - val_accuracy: 0.5294 - val_loss: 1.2921
# Epoch 249/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9403 - loss: 0.1734 - val_accuracy: 0.5882 - val_loss: 1.2733
# Epoch 250/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9552 - loss: 0.1331 - val_accuracy: 0.4706 - val_loss: 1.3978
# Epoch 251/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9254 - loss: 0.2253 - val_accuracy: 0.5294 - val_loss: 1.4652
# Epoch 252/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8657 - loss: 0.2851 - val_accuracy: 0.4706 - val_loss: 1.3770
# Epoch 253/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8955 - loss: 0.1918 - val_accuracy: 0.5294 - val_loss: 1.3615
# Epoch 254/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9701 - loss: 0.1179 - val_accuracy: 0.5882 - val_loss: 1.2468
# Epoch 255/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9552 - loss: 0.1420 - val_accuracy: 0.5882 - val_loss: 1.4010
# Epoch 256/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9851 - loss: 0.0485 - val_accuracy: 0.5882 - val_loss: 1.4389
# Epoch 257/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9104 - loss: 0.1960 - val_accuracy: 0.5294 - val_loss: 1.6800
# Epoch 258/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8657 - loss: 0.3691 - val_accuracy: 0.4118 - val_loss: 2.4226
# Epoch 259/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6119 - loss: 0.9925 - val_accuracy: 0.4706 - val_loss: 1.7920
# Epoch 260/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6866 - loss: 1.0151 - val_accuracy: 0.5882 - val_loss: 1.0926
# Epoch 261/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7612 - loss: 0.5334 - val_accuracy: 0.7059 - val_loss: 0.8691
# Epoch 262/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8806 - loss: 0.3341 - val_accuracy: 0.5294 - val_loss: 1.0067
# Epoch 263/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.8806 - loss: 0.2756 - val_accuracy: 0.5882 - val_loss: 1.0590
# Epoch 264/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8806 - loss: 0.2844 - val_accuracy: 0.4118 - val_loss: 1.2994
# Epoch 265/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8657 - loss: 0.3019 - val_accuracy: 0.5882 - val_loss: 1.2832
# Epoch 266/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9104 - loss: 0.2254 - val_accuracy: 0.5294 - val_loss: 1.2122
# Epoch 267/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9403 - loss: 0.1953 - val_accuracy: 0.4118 - val_loss: 1.3279
# Epoch 268/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9104 - loss: 0.1533 - val_accuracy: 0.5294 - val_loss: 1.3059
# Epoch 269/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9403 - loss: 0.1568 - val_accuracy: 0.5882 - val_loss: 1.5230
# Epoch 270/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9254 - loss: 0.1549 - val_accuracy: 0.4706 - val_loss: 1.4785
# Epoch 271/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9403 - loss: 0.1147 - val_accuracy: 0.4706 - val_loss: 1.5240
# Epoch 272/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.8657 - loss: 0.2445 - val_accuracy: 0.5882 - val_loss: 1.4602
# Epoch 273/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.8806 - loss: 0.2716 - val_accuracy: 0.5294 - val_loss: 1.1693
# Epoch 274/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9104 - loss: 0.1940 - val_accuracy: 0.5882 - val_loss: 2.0279
# Epoch 275/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8657 - loss: 0.3136 - val_accuracy: 0.4706 - val_loss: 2.5691
# Epoch 276/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.5970 - loss: 1.2890 - val_accuracy: 0.4118 - val_loss: 2.6254
# Epoch 277/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.5373 - loss: 1.2668 - val_accuracy: 0.5294 - val_loss: 2.3274
# Epoch 278/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6716 - loss: 1.3233 - val_accuracy: 0.5294 - val_loss: 2.5419
# Epoch 279/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6269 - loss: 2.0173 - val_accuracy: 0.5294 - val_loss: 1.8497
# Epoch 280/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 0.8806 - loss: 0.3316 - val_accuracy: 0.5882 - val_loss: 1.8670
# Epoch 281/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7164 - loss: 0.8980 - val_accuracy: 0.4118 - val_loss: 2.5737
# Epoch 282/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.8358 - loss: 0.6051 - val_accuracy: 0.5294 - val_loss: 1.5681
# Epoch 283/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9254 - loss: 0.2098 - val_accuracy: 0.5882 - val_loss: 1.2922
# Epoch 284/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8806 - loss: 0.2740 - val_accuracy: 0.5882 - val_loss: 1.3382
# Epoch 285/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9254 - loss: 0.1497 - val_accuracy: 0.5882 - val_loss: 1.2886
# Epoch 286/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9254 - loss: 0.1688 - val_accuracy: 0.5882 - val_loss: 1.2411
# Epoch 287/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9254 - loss: 0.1833 - val_accuracy: 0.5882 - val_loss: 1.2765
# Epoch 288/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9403 - loss: 0.1521 - val_accuracy: 0.5294 - val_loss: 1.3290
# Epoch 289/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9701 - loss: 0.0997 - val_accuracy: 0.4706 - val_loss: 1.3437
# Epoch 290/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9701 - loss: 0.0707 - val_accuracy: 0.5882 - val_loss: 1.4137
# Epoch 291/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9851 - loss: 0.0606 - val_accuracy: 0.5294 - val_loss: 1.5218
# Epoch 292/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9851 - loss: 0.0570 - val_accuracy: 0.5294 - val_loss: 1.5176
# Epoch 293/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9552 - loss: 0.1043 - val_accuracy: 0.5294 - val_loss: 1.3813
# Epoch 294/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9104 - loss: 0.1826 - val_accuracy: 0.5882 - val_loss: 1.3728
# Epoch 295/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9851 - loss: 0.0614 - val_accuracy: 0.5294 - val_loss: 1.4917
# Epoch 296/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9701 - loss: 0.0811 - val_accuracy: 0.5882 - val_loss: 1.4917
# Epoch 297/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9403 - loss: 0.1067 - val_accuracy: 0.5882 - val_loss: 1.4471
# Epoch 298/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9403 - loss: 0.1135 - val_accuracy: 0.5882 - val_loss: 1.6666
# Epoch 299/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9552 - loss: 0.1131 - val_accuracy: 0.6471 - val_loss: 1.5590
# Epoch 300/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8657 - loss: 0.2266 - val_accuracy: 0.5294 - val_loss: 1.6509
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Đã lưu mô hình cuối cùng -> /content/drive/MyDrive/nhandangdoan/final_model.h5
# Đang đánh giá trên tập test...
# 1/1 - 0s - 45ms/step - accuracy: 0.5294 - loss: 1.6509
# Độ chính xác trên tập test: 0.5294
# Giao diện nhận diện món ăn đã sẵn sàng!
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://db6712386a28b46e41.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://db6712386a28b46e41.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
